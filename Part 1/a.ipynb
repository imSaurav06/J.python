# %%
a = 5
b = 10.1
c = 'Hello, World!'
d = False
print(type(a),'-',a)
print(type(b),'-',b)
print(type(c),'-',c)
print(type(d),'-',d)
# Out:
# <class 'int'> - 5
# <class 'float'> - 10.1
# <class 'str'> - Hello, World!
# <class 'bool'> - False

# %%
a123 = 5
_b = 10.1111
_ = 'Hello, World!  hello'
d_abc = False

print(type(a123),'-',a123)
print(type(_b),'-',_b)
print(type(_),'-',_)
print(type(d_abc),'-',d_abc)
# Out:
# <class 'int'> - 5
# <class 'float'> - 10.1111
# <class 'str'> - Hello, World!  hello
# <class 'bool'> - False

# %%
_ = 'Hello, World!  hello'
print(type(_),'-',_)
# Out:
# <class 'str'> - Hello, World!  hello

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      5
# a123       int      5
# b          float    10.1
# c          str      Hello, World!
# d          bool     False
# d_abc      bool     False
