# %% [markdown]
# # Lecture 13 – Strings Part 2 (Complete PDF)
# Length Method (len())

# %%
s = "my first salary going to be 7CTC"
s1 = ""
print(len(s1))
print(len(s))
# Out:
# 0
# 32

# %%
s = "my first salary going to be 7CTC"
s = s.lower()
print(s)
s = s.upper()
print(s)
s = s.replace(" ", "  ") 
print(s)
s = s.replace("  ", "") 
print(s)
# Out:
# my first salary going to be 7ctc
# MY FIRST SALARY GOING TO BE 7CTC
# MY  FIRST  SALARY  GOING  TO  BE  7CTC
# MYFIRSTSALARYGOINGTOBE7CTC
