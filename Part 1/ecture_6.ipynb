# %% [markdown]
# Topics Covered (Lecture 1–5 Revision)
# Fundamentals of Data Science & Python
# Variables and Data Types
# Operators in Python
# Built-in Functions (input(), print(), eval(), float(), int())

# %% [markdown]
# Question 1: Mathematical Expression Evaluator
# Problem
#
# Take a mathematical expression from the user, evaluate it, and display the result.

# %%
expression = input("Enter the expression")
result = abs(eval(expression))
print("The result of the expression is ...",result)
# Out:
# The result of the expression is ... 5.429379091346464e+48

# %% [markdown]
# Question 2: House Price Analysis
# Requirements
#
# For User 1 and User 2:
#
# Enter house size
# Enter number of bedrooms
# Enter budget
# Calculate house price

# %%
house_size1 = float(input("Enter the size of the house in square feet: "))
bedrooms_1 = int(input("enter the number of bedrooms: "))
price_1 = float(input("Enter the price of the house: "))

house_size2 = float(input("Enter the size of the house in square feet: "))
bedrooms_2 = int(input("enter the number of bedrooms: "))
price_2 = float(input("Enter the price of the house: "))

house_price1 = house_size1 * 5000
house_price2 = house_size2 * 5000

threshold_price = 7500000

user1_paying_more = house_price1 >= threshold_price # True or False
user2_paying_more = house_price2 >= threshold_price # True or False
print("user 1 is paying more than the threshold price: ", user1_paying_more)
print("user 2 is paying more than the threshold price: ", user2_paying_more)
# Out:
# user 1 is paying more than the threshold price:  False
# user 2 is paying more than the threshold price:  True

# %% [markdown]
# Question 3 :
#
# You are working on a project to analyze stock market data.
# Create variables to store the stock symbol, current price, and percentage change in price. Then, calculate the new price after a 10% increase using arithmetic operators. Finally, prompt the user to enter their budget using the input() function, convert it to a float using the float() function, and compare it with the new price.

# %%
i = 1;
for i in range(10+1):
    print(i)

# %%
for i in range(1,11):
    print(i)

# %%
count = 0

while count < 5:
    print("hello")
    count += 1

print(count)
